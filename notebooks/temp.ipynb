# %%
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

api.dataset_download_files(
    "sshikamaru/car-object-detection", path="../outputs/kaggle/downloaded/", unzip=True
)

print("Dataset downloaded to:", "../outputs/kaggle/downloaded/")

# %%
from rsw_ai.model.YoloDatasetYaml import YoloDatasetYaml

len(YoloDatasetYaml().names)
# Out:
# 2

# %%
from rsw_ai.model.YoloImporter import YoloImporter
from rsw_ai.enum.Dataset import Dataset

YI = YoloImporter()
YI.import_path = "./data/data/train_solution_bounding_boxes (1).csv"
YI.import_dataset(dataset=Dataset.SSHIKAMARU_CAR_OBJECT_DETECTION).dataset_txts
