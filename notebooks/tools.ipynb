# %% [markdown]
# # 1

# %%
from pathlib import Path

Path("../outputs/images/").mkdir(parents=True)
Path("../outputs/metadata/").mkdir(parents=True)

Path("../outputs/exports/yolo/images/train").mkdir(parents=True)
Path("../outputs/exports/yolo/images/val").mkdir(parents=True)
Path("../outputs/exports/yolo/images/test").mkdir(parents=True)
Path("../outputs/exports/yolo/labels/train").mkdir(parents=True)
Path("../outputs/exports/yolo/labels/val").mkdir(parents=True)
Path("../outputs/exports/yolo/labels/test").mkdir(parents=True)


#

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
from rsw_ai.enum.DatasetRepositoryLayout import Dataset

KAGGLE_DOWNLOADED_PATH = "outputs/kaggle/downloaded/"

DIR_DOWNLOADED_SSHIKAMARU_CAR = (
    "../" + KAGGLE_DOWNLOADED_PATH + Dataset.SSHIKAMARU_CAR_OBJECT_DETECTION.label + "/"
)

api = KaggleApi()
api.authenticate()

api.dataset_download_files(
    "sshikamaru/car-object-detection",
    path=DIR_DOWNLOADED_SSHIKAMARU_CAR,
    unzip=True,
)

print(DIR_DOWNLOADED_SSHIKAMARU_CAR)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sshikamaru/car-object-detection
# ../outputs/kaggle/downloaded/sshikamaru_car_object_detection/

# %%
# Out:
# '../outputs/kaggle/downloaded/sshikamaru_car_object_detection/'
