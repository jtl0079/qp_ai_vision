# %% [markdown]
# # Hi, Welcome

# %%
print("Hi, Welcome")

# %% [markdown]
# # Testing

# %% [markdown]
# ## Test create_circle_image

# %%
from rsw_ai.backend.import_nadinpethiyagoda_vehicle_dataset_for_yolo_to_VisionYoloDataset import (
    import_nadinpethiyagoda_vehicle_dataset_for_yolo_to_VisionYoloDataset,
)



vision_yolo_dataset = import_nadinpethiyagoda_vehicle_dataset_for_yolo_to_VisionYoloDataset(
    "../outputs/datasets/downloads/kaggle/nadinpethiyagoda_vehicle_dataset_for_yolo/vehicle dataset/"
)

for split in vision_yolo_dataset.splits:
    for sample in split.samples:
        print(sample.input)
# Out:
# ..\outputs\datasets\downloads\kaggle\nadinpethiyagoda_vehicle_dataset_for_yolo\vehicle dataset\train\images\00043_GMC Savana Van 2012.jpg
# ..\outputs\datasets\downloads\kaggle\nadinpethiyagoda_vehicle_dataset_for_yolo\vehicle dataset\train\images\00077.jpg
# ..\outputs\datasets\downloads\kaggle\nadinpethiyagoda_vehicle_dataset_for_yolo\vehicle dataset\train\images\00116.jpg
# ..\outputs\datasets\downloads\kaggle\nadinpethiyagoda_vehicle_dataset_for_yolo\vehicle dataset\train\images\00175_Ford E-Series Wagon Van 2012.jpg
# ..\outputs\datasets\downloads\kaggle\nadinpethiyagoda_vehicle_dataset_for_yolo\vehicle dataset\train\images\00241.jpg
# ..\outputs\datasets\downloads\kaggle\nadinpethiyagoda_vehicle_dataset_for_yolo\vehicle dataset\train\images\00294.jpg
# ..\outputs\datasets\downloads\kaggle\nadinpethiyagoda_vehicle_dataset_for_yolo\vehicle dataset\train\images\00300_Nissan NV Passenger Van 2012.jpg
# ...

# %% [markdown]
# ## Test

# %%
from rsw_ai.backend.import_sshikamaru_car_object_detection_dataset import (
    import_sshikamaru_car_object_detection_dataset,
)

from PIL import Image
 

vision_yolo_dataset = import_sshikamaru_car_object_detection_dataset(
    "../outputs/datasets/downloads/kaggle/sshikamaru_car_object_detection/data/"
)

for split in vision_yolo_dataset.splits:
    for sample in split.samples:
        print(sample.input)

        with Image.open(sample.input) as img:
            width, height = img.size

        print(width, height)
# Out:
# ..\outputs\datasets\downloads\kaggle\sshikamaru_car_object_detection\data\training_images\vid_4_1000.jpg
# 676 380
# ..\outputs\datasets\downloads\kaggle\sshikamaru_car_object_detection\data\training_images\vid_4_10000.jpg
# 676 380
# ..\outputs\datasets\downloads\kaggle\sshikamaru_car_object_detection\data\training_images\vid_4_10040.jpg
# 676 380
# ..\outputs\datasets\downloads\kaggle\sshikamaru_car_object_detection\data\training_images\vid_4_10020.jpg
# 676 380
# ..\outputs\datasets\downloads\kaggle\sshikamaru_car_object_detection\data\training_images\vid_4_10060.jpg
# 676 380
# ..\outputs\datasets\downloads\kaggle\sshikamaru_car_object_detection\data\training_images\vid_4_10100.jpg
# 676 380
# ..\outputs\datasets\downloads\kaggle\sshikamaru_car_object_detection\data\training_images\vid_4_10120.jpg
# 676 380
# ..\outputs\datasets\downloads\kaggle\sshikamaru_car_object_detection\data\training_images\vid_4_10140.jpg
# 676 380
# ...
